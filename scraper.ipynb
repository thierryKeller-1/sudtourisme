# %%
from botasaurus.browser import Driver
from botasaurus.soupify import soupify
import time

driver = Driver()

date_start = "11/03/2026"
date_end = "12/03/2026"

driver.get("https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art")

time.sleep(5)

driver.click_element_containing_text("Accepter")

driver.get_cookies()

driver.click_element_containing_text("XPF")

time.sleep(1)

driver.click_element_containing_text("EUR")

driver.scroll_into_view("input[id='datepicker-v-0-1-1-0-start']")
time.sleep(1)

driver.run_js(f"""
let date_start = document.getElementById('datepicker-v-0-1-1-0-start');
date_start.value = "{date_start}";

date_start.scrollIntoView();

date_start.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_start.dispatchEvent(new Event('change', {{ bubbles : true }} ));

let date_end = document.getElementById('datepicker-v-0-1-1-0-end');
date_end.value = "{date_end}";

date_end.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_end.dispatchEvent(new Event('change', {{ bubbles : true }} ));
""")

driver.click_element_containing_text("Rechercher")

# %%
from botasaurus.browser import Driver
from botasaurus.soupify import soupify
import time

# %%
driver = Driver()

# %%
date_start = "13/03/2026"
date_end = "14/03/2026"

# %%
driver.get("https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art")
# Out:
# <Tab [40DCFE5218F5AC0DDAFA90D4E701FBF6] [page] [url: https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art]>

# %%
time.sleep(5)

# %%
driver.click_element_containing_text("Accepter")

# %%
driver.get_cookies()
# Out:
# [{'name': 'NID',
#   'value': '529=sWE1XeF_Zbit_YprdWlWIVqQdC0VbIEGLdh28XkIkp5HSD299J-L36tAObbkqTJijYb8royKS8OXDkVapgogugxF5ps_CSCoOkxhPE3VhkobCpoQCT79tout80qmYdDEKwnCC-RkXuuSShKgUEOWkB9uoscw2eN7uOlyp-NNtZd3R50_r9R1vtoYWfGckUXVNJ6NxHLbuDMJWz7HUQ',
#   'domain': '.google.com',
#   'path': '/',
#   'expires': 1789042431.085659,
#   'size': 217,
#   'httpOnly': True,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'i18n_redirected',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1804767239.106693,
#   'size': 17,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme_lang',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': -1,
#   'size': 18,
#   'httpOnly': False,
#   'secure': False,
#   'session': True,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme-rgpd',
#   'value': 'eyJhbmFseXRpY190cmFja2VyIjp0cnVlLCJjb25maXJtZWQiOnRydWUsImFsbCI6dHJ1ZX0%3D',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1804767259,
#   'size': 90,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_pk_id.68.7a38',
#   'value': '980c79e55cca9467.1773231260.',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1807186460,
#   'size': 42,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_pk_ses.68.7a38',
#   'value': '1',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1773233060,
#   'size': 16,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_gcl_au',
#   'value': '1.1.663065772.1773231261',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1781007261,
#   'size': 31,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_ga_ND5F5TX0V6',
#   'value': 'GS2.1.s1773231260$o1$g0$t1773231260$j60$l0$h0',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1807791260.717384,
#   'size': 59,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_ga',
#   'value': 'GA1.1.1052789463.1773231261',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1807791260.717917,
#   'size': 30,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_fbp',
#   'value': 'fb.1.1773231261104.560721157497236172',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1781007261,
#   'size': 41,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_hjSessionUser_5318469',
#   'value': 'eyJpZCI6ImI0MTMxZTA1LWYzMDctNWRhZi05ZjBlLWUwYzAwM2E5OWY2MiIsImNyZWF0ZWQiOjE3NzMyMzEyNjE1MjQsImV4aXN0aW5nIjp0cnVlfQ==',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1804767261,
#   'size': 138,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_hjSession_5318469',
#   'value': 'eyJpZCI6IjVmYzIwMTUzLWQzZDMtNDE2Zi1hZmZmLTlkM2VjMTUzMmE5MCIsImMiOjE3NzMyMzEyNjE1MjYsInMiOjEsInIiOjEsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1773233061,
#   'size': 166,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'test_cookie',
#   'value': 'CheckForPermission',
#   'domain': '.doubleclick.net',
#   'path': '/',
#   'expires': 1773232161.956731,
#   'size': 29,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'crisp-client%2Fsession%2F039b5734-0f14-45db-a696-a5177bcec0b9',
#   'value': 'session_da07444b-82ae-40cf-ab5f-4e44ff7e629a',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1788999262,
#   'size': 105,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_dd_s',
#   'value': 'rum=2&id=cc7a7c35-54e9-41bf-bae2-bf4f768915e2&created=1773231259412&expire=1773232219415',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1773232230,
#   'size': 93,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Strict',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443}]

# %%
driver.run_js(f"""
let date_start = document.getElementById('datepicker-v-0-1-8-0-start');
date_start.value = "{date_start}";

date_start.scrollIntoView();

date_start.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_start.dispatchEvent(new Event('change', {{ bubbles : true }} ));

let date_end = document.getElementById('datepicker-v-0-1-8-0-end');
date_end.value = "{date_end}";

date_end.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_end.dispatchEvent(new Event('change', {{ bubbles : true }} ));
""")

# %%
time.sleep(1)

# %%
driver.click_element_containing_text("Rechercher")

# %%
driver.get_cookies()
# Out:
# [{'name': 'i18n_redirected',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1783797700.604897,
#   'size': 17,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'NID',
#   'value': '528=ZfPxSbWHmDdokVdsNq4lAHI-7A81TmC9myJT7zxhAQ8wOi-y9aHt8rXVf6_gxVv_k7v1r6Vcge9xYbE5j6aaErya724XJmHyEUoP2pY7CjQU7DzCGc8EDPJ6IPNUkGQIamf6pPCsXNdFhhVwoKPjnwNE_xnnvm52wocF-2CchMpo4_PRDs6BHq1WDWZ21WcNhLcb85ZKuW0GLMEw',
#   'domain': '.google.com',
#   'path': '/',
#   'expires': 1768072902.450427,
#   'size': 215,
#   'httpOnly': True,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme_lang',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': -1,
#   'size': 18,
#   'httpOnly': False,
#   'secure': False,
#   'session': True,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme-rgpd',
#   'value': 'eyJhbmFseXRpY190cmFja2VyIjp0cnVlLCJjb25maXJtZWQiOnRydWUsImFsbCI6dHJ1ZX0%3D',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1783797710,
#   'size': 90,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_pk_id.68.7a38',
#   'value': 'b6a19a4dca19eee9.1752261711.',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1786216911,
#   'size': 42,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_pk_ses.68.7a38',
#   'value': '1',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1752263511,
#   'size': 16,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_ga_ND5F5TX0V6',
#   'value': 'GS2.1.s1752261711$o1$g0$t1752261711$j60$l0$h0',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1786821711.552633,
#   'size': 59,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_ga',
#   'value': 'GA1.1.1643026117.1752261712',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1786821711.553556,
#   'size': 30,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_gcl_au',
#   'value': '1.1.1121326430.1752261712',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1760037712,
#   'size': 32,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_hjSessionUser_5318469',
#   'value': 'eyJpZCI6IjcxYTVjYjU2LWU5NzYtNWNmMC04ZGYzLWY2NjNkMTgyOTE4YiIsImNyZWF0ZWQiOjE3NTIyNjE3MTI1MjAsImV4aXN0aW5nIjpmYWxzZX0=',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1783797712,
#   'size': 138,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_hjSession_5318469',
#   'value': 'eyJpZCI6IjdiODRhYjI4LTBmNzctNGRiYS05MTNjLTM0N2Y2YTFiODgyOCIsImMiOjE3NTIyNjE3MTI1MjEsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1752263512,
#   'size': 166,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'i18n_currency',
#   'value': 'EUR',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': -1,
#   'size': 16,
#   'httpOnly': False,
#   'secure': False,
#   'session': True,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'test_cookie',
#   'value': 'CheckForPermission',
#   'domain': '.doubleclick.net',
#   'path': '/',
#   'expires': 1752262613.03954,
#   'size': 29,
#   'httpOnly': False,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_fbp',
#   'value': 'fb.1.1752261713081.338319585301500628',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1760037713,
#   'size': 41,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'crisp-client%2Fsession%2F039b5734-0f14-45db-a696-a5177bcec0b9',
#   'value': 'session_0bbc3be1-8758-48e9-b783-7acfa714a566',
#   'domain': '.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1768029713,
#   'size': 105,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': '_dd_s',
#   'value': 'rum=1&id=3c589c74-203a-4456-9c73-f2937a46390f&created=1752261710294&expire=1752262613518',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1752262615,
#   'size': 93,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Strict',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443}]

# %%
# driver.add_cookies({'name': 'i18n_currency', 'value': 'EUR', 'path': '/', 'domain': 'www.book-sudtourisme.com'})

# %%
name = driver.get_text("h1[class='hn']")
name
# Out:
# 'GONDWANA CITY GREEN & ART'

# %%
driver.get_text("a[id='_d6fvjqzs.yz76ch5j.za4ds10u.ifutabet.dy8sg6w9']")
# Out:
# '19 rue Auguste Brun,Quartier Latin, 98800 Nouméa, NOUVELLE-CALÉDONIE'

# %%
len(driver.select("div[id='_jrwmov0d.r0rmbvhs']").select_all('li[class="flex flex-col h-full justify-between p-4 rounded-md border-2 border-gray-600 hover:bg-gray-200 cursor-pointer"]'))
# Out:
# 11

# %%
soupe = soupify(driver.page_html)

# %%
cards = soupe.find("div", {'id':'_jrwmov0d.r0rmbvhs'}).find_all('li', {'class':"flex flex-col h-full justify-between p-4 rounded-md border-2 border-gray-600 hover:bg-gray-200 cursor-pointer"})

# %%
len(cards)
# Out:
# 11

# %%
price_text = cards[0].find('span', {'class':'text-xl text-primary font-bold'}).text.replace(',','.').split(' ')
price_text
# Out:
# ['16826', 'XPF']

# %%
typologie = cards[0].find('h3', {'class':'font-semibold'}).text.strip()
typologie
# Out:
# 'Chambre Accessible'

# %%
dates = cards[0].find('p', {'class':'font-semibold'}).text.strip().replace('Du ', '').split(' au ')

# %%
start_date = dates[0]
start_date
# Out:
# '13/03/2026'

# %%
end_date = dates[1]
end_date
# Out:
# '14/03/2026'

# %%
price = price_text[0]
price
# Out:
# '142.00'

# %%
curency = price_text[1]
curency
# Out:
# 'XPF'

# %%
SUDTOURISME_FIELDS = [
            'web-scraper-order',
            'date_price',
            'date_debut', 
            'date_fin',
            'prix_init',
            'prix_actuel',
            'typologie',
            'n_offre',
            'curency',
            'nom',
            'localite',
            'date_debut-jour',
            'Nb semaines'
        ]

# %%
from urllib.parse import urlparse, parse_qs

# %%
parse_qs(urlparse("https://www.book-sudtourisme.com/reserver-mon-hebergement/rivland-resort?checkin=2026-01-14&checkout=2026-01-15").query)
# Out:
# {'checkin': ['2026-01-14'], 'checkout': ['2026-01-15']}
