# %%
from botasaurus.browser import Driver
from botasaurus.soupify import soupify
import time

driver = Driver()

date_start = "17/01/2026"
date_end = "18/01/2026"

driver.get("https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art")

time.sleep(5)

driver.click_element_containing_text("Accepter")

driver.get_cookies()

driver.click_element_containing_text("XPF")

time.sleep(1)

driver.click_element_containing_text("EUR")

driver.scroll_into_view("input[id='datepicker-v-0-1-1-0-start']")
time.sleep(1)

driver.run_js(f"""
let date_start = document.getElementById('datepicker-v-0-1-1-0-start');
date_start.value = "{date_start}";

date_start.scrollIntoView();

date_start.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_start.dispatchEvent(new Event('change', {{ bubbles : true }} ));

let date_end = document.getElementById('datepicker-v-0-1-1-0-end');
date_end.value = "{date_end}";

date_end.dispatchEvent(new Event('input', {{ bubbles : true }} ));
date_end.dispatchEvent(new Event('change', {{ bubbles : true }} ));
""")

driver.click_element_containing_text("Rechercher")

# %%
from botasaurus.browser import Driver
from botasaurus.soupify import soupify
import time

# %%
driver = Driver()

# %%
date_start = "13/01/2026"
date_end = "14/01/2026"

# %%
driver.get("https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art")
# Out:
# <Tab [CA0326ED51BB053B41E32CEA5F4F6787] [page] [url: https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art]>

# %%
time.sleep(5)

# %%
driver.click_element_containing_text("Accepter")

# %%
driver.get_cookies()
# Out:
# [{'name': 'NID',
#   'value': '528=M9ng0ITsFmaVyxWQqcULe0ZiDswXf9azY_TWw7YBKpXwgCK5Y4ahaFvEhApCt1OjpznGDH8PSBB6vG_k3QFdIGnoTunBGZNtBlRmVn_c_kl384tQgUbyA-_cUN_7NavoNGYc1A7hogR9oBHIlk2UbyqwwMXkaEPbUOq0DfY9XwalC03i6aY71wIE96PisVgh53Dk3DV5CYGOYug',
#   'domain': '.google.com',
#   'path': '/',
#   'expires': 1784033871.62459,
#   'size': 214,
#   'httpOnly': True,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'i18n_redirected',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1799758677.267719,
#   'size': 17,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme_lang',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
# ...

# %%
driver.click_element_containing_text("XPF")

# %%
time.sleep(1)

# %%
driver.click_element_containing_text("EUR")

# %%
driver.scroll_into_view("input[id='datepicker-v-0-1-1-0-start']")
time.sleep(1)

# %%
driver.run_js(f"""
              document.querySelector("input[id='datepicker-v-0-1-1-0-start']").value = "{date_start}";
              document.querySelector("input[id='datepicker-v-0-1-1-0-end']").value = "{date_end}";        
              """)

# %%
driver.click_element_containing_text("Rechercher")

# %%
driver.run_js(f"""
              document.querySelector("input[id='datepicker-v-0-1-1-0-start']").value = "{"/".join(list(date_start.split('/'))[::-1])}";
              document.querySelector("input[id='datepicker-v-0-1-1-0-end']").value = "{"/".join(list(date_end.split('/'))[::-1])}";        
                            """)

# %%
date_start
# Out:
# '12/01/2026'

# %%
driver.reload()
# Out:
# <Tab [F0E44540D1A7F89DEE8C838B612173BD] [page] [url: https://www.book-sudtourisme.com/reserver-mon-hebergement/gondwana-city-green-and-art]>

# %%
driver.click("input[id='datepicker-v-0-1-1-0-start']")

# %%
driver.move_mouse_to_element("input[id='datepicker-v-0-1-1-0-start']")
driver.run_js(f"""
              document.querySelector("input[id='datepicker-v-0-1-1-0-start']").value = "{date_start}";      
              """)
time.sleep(1)
driver.click_element_containing_text("12")
time.sleep(1)
driver.move_mouse_to_element("input[id='datepicker-v-0-1-1-0-end']")
driver.run_js(f"""
              document.querySelector("input[id='datepicker-v-0-1-1-0-start']").value = "{date_end}";      
              """)
time.sleep(1)
driver.click_element_containing_text("13")

# %%
driver.move_mouse_to_element("input[id='datepicker-v-0-1-1-0-start']")
driver.select("input[id='datepicker-v-0-1-1-0-start']").set_value(date_start)
time.sleep(1)
driver.click_element_containing_text("12")
driver.move_mouse_to_element("input[id='datepicker-v-0-1-1-0-end']")
driver.select("input[id='datepicker-v-0-1-1-0-end']").set_value(date_end)
driver.click_element_containing_text("13")

# %%
driver.select("input[id='datepicker-v-0-1-1-0-end']").set_value(date_end)

# %%
driver.click_element_containing_text("Rechercher")

# %%
driver.get_cookies()
# Out:
# [{'name': 'i18n_redirected',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
#   'expires': 1783797700.604897,
#   'size': 17,
#   'httpOnly': False,
#   'secure': False,
#   'session': False,
#   'sameSite': 'Lax',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'NID',
#   'value': '528=ZfPxSbWHmDdokVdsNq4lAHI-7A81TmC9myJT7zxhAQ8wOi-y9aHt8rXVf6_gxVv_k7v1r6Vcge9xYbE5j6aaErya724XJmHyEUoP2pY7CjQU7DzCGc8EDPJ6IPNUkGQIamf6pPCsXNdFhhVwoKPjnwNE_xnnvm52wocF-2CchMpo4_PRDs6BHq1WDWZ21WcNhLcb85ZKuW0GLMEw',
#   'domain': '.google.com',
#   'path': '/',
#   'expires': 1768072902.450427,
#   'size': 215,
#   'httpOnly': True,
#   'secure': True,
#   'session': False,
#   'sameSite': 'None',
#   'priority': 'Medium',
#   'sameParty': False,
#   'sourceScheme': 'Secure',
#   'sourcePort': 443},
#  {'name': 'sudtourisme_lang',
#   'value': 'fr',
#   'domain': 'www.book-sudtourisme.com',
#   'path': '/',
# ...

# %%
# driver.add_cookies({'name': 'i18n_currency', 'value': 'EUR', 'path': '/', 'domain': 'www.book-sudtourisme.com'})

# %%
name = driver.get_text("h1[class='hn']")
name
# Out:
# 'GONDWANA CITY GREEN & ART'

# %%
driver.get_text("a[id='_d6fvjqzs.yz76ch5j.za4ds10u.ifutabet.dy8sg6w9']")
# Out:
# '19 rue Auguste Brun,Quartier Latin, 98800 Nouméa, NOUVELLE-CALÉDONIE'

# %%
len(driver.select("div[id='_jrwmov0d.r0rmbvhs']").select_all('li[class="flex flex-col h-full justify-between p-4 rounded-md border-2 border-gray-600 hover:bg-gray-200 cursor-pointer"]'))
# Out:
# 0

# %%
soupe = soupify(driver.page_html)

# %%
cards = soupe.find("div", {'id':'_jrwmov0d.r0rmbvhs'}).find_all('li', {'class':"flex flex-col h-full justify-between p-4 rounded-md border-2 border-gray-600 hover:bg-gray-200 cursor-pointer"})

# %%
price_text = cards[0].find('span', {'class':'text-xl text-primary font-bold'}).text.replace(',','.').split(' ')
price_text

# %%
typologie = cards[0].find('h3', {'class':'font-semibold'}).text.strip()
typologie
# Out:
# 'Queen Room'

# %%
dates = cards[0].find('p', {'class':'font-semibold'}).text.strip().replace('Du ', '').split(' au ')

# %%
start_date = dates[0]
start_date
# Out:
# '10/01/2026'

# %%
end_date = dates[1]
end_date
# Out:
# '11/01/2026'

# %%
price = price_text[0]
price
# Out:
# '142.00'

# %%
curency = price_text[1]
curency
# Out:
# '€'

# %%
SUDTOURISME_FIELDS = [
            'web-scraper-order',
            'date_price',
            'date_debut', 
            'date_fin',
            'prix_init',
            'prix_actuel',
            'typologie',
            'n_offre',
            'curency',
            'nom',
            'localite',
            'date_debut-jour',
            'Nb semaines'
        ]

# %%
from urllib.parse import urlparse, parse_qs

# %%
parse_qs(urlparse("https://www.book-sudtourisme.com/reserver-mon-hebergement/rivland-resort?checkin=2026-01-14&checkout=2026-01-15").query)
# Out:
# {'checkin': ['2026-01-14'], 'checkout': ['2026-01-15']}
