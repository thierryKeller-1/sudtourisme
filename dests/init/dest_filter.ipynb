# %%
file_1 = "ficher ancien dest" #path fichier dest_1
file_2 = "ficher nouveu dest" #path fichier dest_2

files = file_1 + file_2
new_files = []
for x in files:
    if x in new_files:
        continue
    new_files.append(x)
print(len(files))
print(len(new_files))
